# %% [markdown]
# # Introduction
# Do you ever feel alone in the world? Do you wish you had someone to talk to. Here is a notebook. It won't solve your problems. Only you can do that. And it won't make it easier either. But it will be here for you. It will never leave you. I know you've heard this before. And I know people have let you down. This notebook can't change this. It's just a notebook. But if you let it into your heart, you will have done something profound. You will have made a change to your life. A change you wanted to make. And this notebook will symbolize this. It will remind you that you are not powerless, that you don't have to be a victim of life and your circumstances.

# %% [markdown]
# # Calculating pi using Monte Carlo methods

# %% [markdown]
# ## Relevant formulas
#
# - square area: $s = (2 r)^2$
# - circle area: $c = \pi r^2$
# - $c/s = (\pi r^2) / (4 r^2) = \pi / 4$
# - $\pi = 4 * c/s$

# %% [markdown]
# ## Image to visualize the concept
#
# ![Darts](https://raw.githubusercontent.com/coderefinery/jupyter/main/example/darts.svg)

# %%
# importing modules that we will need

import random
import matplotlib.pyplot as plt

# %%
# initializing the number of "throws"

num_points = 100000

# %%
# here we "throw darts" and count the number of hits

points = []
hits = 0
for _ in range(num_points):
    x, y = random.random(), random.random()
    if x*x + y*y < 1.0:
        hits += 1
        points.append((x, y, "green"))
    else:
        points.append((x, y, "blue"))

# %% [markdown]
# The smart thing is to not use append. Instead, make an array of zeros of a known lenght.

# %%
# unzip points into 3 lists
x, y, colors = zip(*points)

# define figure dimensions
fig, ax = plt.subplots()
fig.set_size_inches(6.0, 6.0)

# plot results
ax.scatter(x, y, c=colors)

# %%
# compute and print the estimate

fraction = hits / num_points
4 * fraction
# Out:
# 3.14348
